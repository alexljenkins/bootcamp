# %%
import pandas as pd

df = pd.read_csv('large_countries_2015.csv')

# %%
df.rename(columns={'Unnamed: 0': 'countries'}, inplace=True)
df.head()
# Out:
#     countries    population  fertility      continent
# 0  Bangladesh  1.609956e+08       2.12           Asia
# 1      Brazil  2.078475e+08       1.78  South America
# 2       China  1.376049e+09       1.57           Asia
# 3       India  1.311051e+09       2.43           Asia
# 4   Indonesia  2.575638e+08       2.28           Asia

# %% [markdown]
# ### 1) Set index

# %%
df.set_index('countries', inplace=True) #cant run twice because the column no longer exists

# %%
df.head()
# Out:
#               population  fertility      continent
# countries
# Bangladesh  1.609956e+08       2.12           Asia
# Brazil      2.078475e+08       1.78  South America
# China       1.376049e+09       1.57           Asia
# India       1.311051e+09       2.43           Asia
# Indonesia   2.575638e+08       2.28           Asia

# %% [markdown]
# ### 2) reset index

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#     countries    population  fertility      continent
# 0  Bangladesh  1.609956e+08       2.12           Asia
# 1      Brazil  2.078475e+08       1.78  South America
# 2       China  1.376049e+09       1.57           Asia
# 3       India  1.311051e+09       2.43           Asia
# 4   Indonesia  2.575638e+08       2.28           Asia

# %% [markdown]
# ### 3) groupby() to set index

# %%
# Out:
#         countries    population  fertility      continent
# 0      Bangladesh  1.609956e+08       2.12           Asia
# 1          Brazil  2.078475e+08       1.78  South America
# 2           China  1.376049e+09       1.57           Asia
# 3           India  1.311051e+09       2.43           Asia
# 4       Indonesia  2.575638e+08       2.28           Asia
# 5           Japan  1.265735e+08       1.45           Asia
# 6          Mexico  1.270172e+08       2.13  North America
# 7         Nigeria  1.822020e+08       5.89         Africa
# 8        Pakistan  1.889249e+08       3.04           Asia
# 9     Philippines  1.006994e+08       2.98           Asia
# 10         Russia  1.434569e+08       1.61         Europe
# 11  United States  3.217736e+08       1.97  North America

# %%
df.groupby('continent').mean()
# Out:
#                  population  fertility
# continent
# Africa         1.822020e+08   5.890000
# Asia           5.031224e+08   2.267143
# Europe         1.434569e+08   1.610000
# North America  2.243954e+08   2.050000
# South America  2.078475e+08   1.780000

# %% [markdown]
# ### 4) Hierarchical Indexing

# %%
#cannot sort by index. must reset and move back in
sort = df.sort_values(['continent','countries'])
h = sort.set_index(['continent','countries'])

# %%
#cannot just search "all" then "China"
#Must specify both in indexing order
h.loc['Asia']
# Out:
#                population  fertility
# countries
# Bangladesh   1.609956e+08       2.12
# China        1.376049e+09       1.57
# India        1.311051e+09       2.43
# Indonesia    2.575638e+08       2.28
# Japan        1.265735e+08       1.45
# Pakistan     1.889249e+08       3.04
# Philippines  1.006994e+08       2.98

# %%
h.head()
# Out:
#                         population  fertility
# continent countries
# Africa    Nigeria     1.822020e+08       5.89
# Asia      Bangladesh  1.609956e+08       2.12
#           China       1.376049e+09       1.57
#           India       1.311051e+09       2.43
#           Indonesia   2.575638e+08       2.28

# %%
#you can also use groupby as well
grouped = df.groupby(['continent','countries']).first()
grouped.head()
# Out:
#                         population  fertility
# continent countries
# Africa    Nigeria     1.822020e+08       5.89
# Asia      Bangladesh  1.609956e+08       2.12
#           China       1.376049e+09       1.57
#           India       1.311051e+09       2.43
#           Indonesia   2.575638e+08       2.28

# %%
df.head()
# Out:
#     countries    population  fertility      continent
# 0  Bangladesh  1.609956e+08       2.12           Asia
# 1      Brazil  2.078475e+08       1.78  South America
# 2       China  1.376049e+09       1.57           Asia
# 3       India  1.311051e+09       2.43           Asia
# 4   Indonesia  2.575638e+08       2.28           Asia

# %% [markdown]
# # Stacking and Unstacking

# %%
df = pd.read_csv('large_countries_2015.csv')
df.set_index('countries', inplace=True)
df.drop('continent', axis=1, inplace=True) #deletes a column (default is rows)

# %%
long = df.stack() #creates a long form on the data
long.head()
# Out:
# countries
# Bangladesh  population    1.609956e+08
#             fertility     2.120000e+00
# Brazil      population    2.078475e+08
#             fertility     1.780000e+00
# China       population    1.376049e+09
# dtype: float64

# %%
long.unstack()
# Out:
#                  population  fertility
# countries
# Bangladesh     1.609956e+08       2.12
# Brazil         2.078475e+08       1.78
# China          1.376049e+09       1.57
# India          1.311051e+09       2.43
# Indonesia      2.575638e+08       2.28
# Japan          1.265735e+08       1.45
# Mexico         1.270172e+08       2.13
# Nigeria        1.822020e+08       5.89
# Pakistan       1.889249e+08       3.04
# Philippines    1.006994e+08       2.98
# Russia         1.434569e+08       1.61
# United States  3.217736e+08       1.97
